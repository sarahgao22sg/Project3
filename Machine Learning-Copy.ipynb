# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from geopy.geocoders import Nominatim

# %%
file_path = os.path.join("Resources", "Exotic - Zebra Mussels.csv")
zebra_mussels = pd.read_csv(file_path)

zebra_mussels
# Out:
#       Specimen Number  Species ID              Group        Family  \
# 0              615085           5  Mollusks-Bivalves  Dreissenidae
# 1              615297           5  Mollusks-Bivalves  Dreissenidae
# 2              615300           5  Mollusks-Bivalves  Dreissenidae
# 3              615301           5  Mollusks-Bivalves  Dreissenidae
# 4              615302           5  Mollusks-Bivalves  Dreissenidae
# ...               ...         ...                ...           ...
# 7925           118181           5  Mollusks-Bivalves  Dreissenidae
# 7926           118184           5  Mollusks-Bivalves  Dreissenidae
# 7927           118438           5  Mollusks-Bivalves  Dreissenidae
# 7928           541415           5  Mollusks-Bivalves  Dreissenidae
# 7929           541258           5  Mollusks-Bivalves  Dreissenidae
#
#            Scientific Name   Common Name                   Country     State  \
# 0     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 1     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 2     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 3     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 4     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# ...                    ...           ...                       ...       ...
# 7925  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7926  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7927  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7928  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7929  Dreissena polymorpha  zebra mussel  United States of America        WV
#
#      County                                           Locality  ...  Title 5  \
# 0       NaN  Lake Winnipeg, at Winnipeg Beach, Manitoba, Ca...  ...      NaN
# 1       NaN  Lake Winnipeg, at Gimli Harbour, Manitoba, Canada  ...      NaN
# 2       NaN   Lake Winnipeg, at Willow Point, Manitoba, Canada  ...      NaN
# 3       NaN  Lake Winnipeg, at Silver Harbour, Manitoba, Ca...  ...      NaN
# 4       NaN  Lake Winnipeg, at Balsam Bay Harbour, Manitoba...  ...      NaN
# ...     ...                                                ...  ...      ...
# 7925   Wood  Ohio River (R.M. 205) [just below Belleville L...  ...      NaN
# 7926   Wood  Ohio River (R.M. 176) at Muskingum Island at B...  ...      NaN
# 7927   Wood  Ohio River (R.M. 175.2) about 3 miles downrive...  ...      NaN
# 7928   Wood  Ohio River at RM 205.2, ORSANCO survey site OH...  ...      NaN
# 7929   Wood  Ohio River at RM 204.4, ORSANCO survey site OH...  ...      NaN
#
#       Publisher 5 Location 5 Reference 6 Type 6  Date 6  Author 6  Title 6  \
# 0             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 1             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 2             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 3             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 4             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# ...           ...        ...         ...    ...     ...       ...      ...
# 7925          NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 7926          NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 7927          NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 7928          NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 7929          NaN        NaN         NaN    NaN     NaN       NaN      NaN
#
#       Publisher 6 Location 6
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ...           ...        ...
# 7925          NaN        NaN
# 7926          NaN        NaN
# 7927          NaN        NaN
# 7928          NaN        NaN
# 7929          NaN        NaN
#
# [7930 rows x 67 columns]

# %%
zebra_mussels[zebra_mussels["Latitude"] == 0]
# Out:
#       Specimen Number  Species ID              Group        Family  \
# 5935           749843           5  Mollusks-Bivalves  Dreissenidae
#
#            Scientific Name   Common Name                   Country State  \
# 5935  Dreissena polymorpha  zebra mussel  United States of America    OH
#
#          County   Locality  ...  Title 5  Publisher 5 Location 5 Reference 6  \
# 5935  Fairfield  Long Lake  ...      NaN          NaN        NaN         NaN
#
#      Type 6  Date 6  Author 6  Title 6  Publisher 6 Location 6
# 5935    NaN     NaN       NaN      NaN          NaN        NaN
#
# [1 rows x 67 columns]

# %%
zebra_mussels = zebra_mussels[zebra_mussels["Latitude"] != 0]
zebra_mussels
# Out:
#       Specimen Number  Species ID              Group        Family  \
# 0              615085           5  Mollusks-Bivalves  Dreissenidae
# 1              615297           5  Mollusks-Bivalves  Dreissenidae
# 2              615300           5  Mollusks-Bivalves  Dreissenidae
# 3              615301           5  Mollusks-Bivalves  Dreissenidae
# 4              615302           5  Mollusks-Bivalves  Dreissenidae
# ...               ...         ...                ...           ...
# 7925           118181           5  Mollusks-Bivalves  Dreissenidae
# 7926           118184           5  Mollusks-Bivalves  Dreissenidae
# 7927           118438           5  Mollusks-Bivalves  Dreissenidae
# 7928           541415           5  Mollusks-Bivalves  Dreissenidae
# 7929           541258           5  Mollusks-Bivalves  Dreissenidae
#
#            Scientific Name   Common Name                   Country     State  \
# 0     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 1     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 2     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 3     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 4     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# ...                    ...           ...                       ...       ...
# 7925  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7926  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7927  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7928  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7929  Dreissena polymorpha  zebra mussel  United States of America        WV
#
#      County                                           Locality  ...  Title 5  \
# 0       NaN  Lake Winnipeg, at Winnipeg Beach, Manitoba, Ca...  ...      NaN
# 1       NaN  Lake Winnipeg, at Gimli Harbour, Manitoba, Canada  ...      NaN
# 2       NaN   Lake Winnipeg, at Willow Point, Manitoba, Canada  ...      NaN
# 3       NaN  Lake Winnipeg, at Silver Harbour, Manitoba, Ca...  ...      NaN
# 4       NaN  Lake Winnipeg, at Balsam Bay Harbour, Manitoba...  ...      NaN
# ...     ...                                                ...  ...      ...
# 7925   Wood  Ohio River (R.M. 205) [just below Belleville L...  ...      NaN
# 7926   Wood  Ohio River (R.M. 176) at Muskingum Island at B...  ...      NaN
# 7927   Wood  Ohio River (R.M. 175.2) about 3 miles downrive...  ...      NaN
# 7928   Wood  Ohio River at RM 205.2, ORSANCO survey site OH...  ...      NaN
# 7929   Wood  Ohio River at RM 204.4, ORSANCO survey site OH...  ...      NaN
#
#       Publisher 5 Location 5 Reference 6 Type 6  Date 6  Author 6  Title 6  \
# 0             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 1             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 2             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 3             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 4             NaN        NaN         NaN    NaN     NaN       NaN      NaN
# ...           ...        ...         ...    ...     ...       ...      ...
# 7925          NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 7926          NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 7927          NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 7928          NaN        NaN         NaN    NaN     NaN       NaN      NaN
# 7929          NaN        NaN         NaN    NaN     NaN       NaN      NaN
#
#       Publisher 6 Location 6
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ...           ...        ...
# 7925          NaN        NaN
# 7926          NaN        NaN
# 7927          NaN        NaN
# 7928          NaN        NaN
# 7929          NaN        NaN
#
# [7929 rows x 67 columns]

# %%
wanted_columns = ["Specimen Number", "Species ID", "Group", "Family", "Scientific Name", "Common Name", "Country", "State", "County", "Locality", "Latitude", "Longitude", "Drainage Name", "Year", "Month", "Day"]
zebra_mussels = zebra_mussels[wanted_columns]
zebra_mussels.head()
# Out:
#    Specimen Number  Species ID              Group        Family  \
# 0           615085           5  Mollusks-Bivalves  Dreissenidae
# 1           615297           5  Mollusks-Bivalves  Dreissenidae
# 2           615300           5  Mollusks-Bivalves  Dreissenidae
# 3           615301           5  Mollusks-Bivalves  Dreissenidae
# 4           615302           5  Mollusks-Bivalves  Dreissenidae
#
#         Scientific Name   Common Name Country     State County  \
# 0  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 1  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 2  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 3  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 4  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
#
#                                             Locality  Latitude  Longitude  \
# 0  Lake Winnipeg, at Winnipeg Beach, Manitoba, Ca...  50.50821  -96.96738
# 1  Lake Winnipeg, at Gimli Harbour, Manitoba, Canada  50.63182  -96.98356
# 2   Lake Winnipeg, at Willow Point, Manitoba, Canada  50.60386  -96.95781
# 3  Lake Winnipeg, at Silver Harbour, Manitoba, Ca...  50.81161  -96.96326
# 4  Lake Winnipeg, at Balsam Bay Harbour, Manitoba...  50.47381  -96.58357
#
#   Drainage Name  Year  Month   Day
# 0           NaN  2013   10.0  17.0
# 1           NaN  2013   10.0  11.0
# 2           NaN  2013   10.0   NaN
# 3           NaN  2013   10.0   NaN
# 4           NaN  2013   10.0   NaN

# %%
zebra_mussels = zebra_mussels.dropna(how='any', subset=['Latitude', 'Longitude'])
zebra_mussels
# Out:
#       Specimen Number  Species ID              Group        Family  \
# 0              615085           5  Mollusks-Bivalves  Dreissenidae
# 1              615297           5  Mollusks-Bivalves  Dreissenidae
# 2              615300           5  Mollusks-Bivalves  Dreissenidae
# 3              615301           5  Mollusks-Bivalves  Dreissenidae
# 4              615302           5  Mollusks-Bivalves  Dreissenidae
# ...               ...         ...                ...           ...
# 7925           118181           5  Mollusks-Bivalves  Dreissenidae
# 7926           118184           5  Mollusks-Bivalves  Dreissenidae
# 7927           118438           5  Mollusks-Bivalves  Dreissenidae
# 7928           541415           5  Mollusks-Bivalves  Dreissenidae
# 7929           541258           5  Mollusks-Bivalves  Dreissenidae
#
#            Scientific Name   Common Name                   Country     State  \
# 0     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 1     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 2     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 3     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# 4     Dreissena polymorpha  zebra mussel                    Canada  Manitoba
# ...                    ...           ...                       ...       ...
# 7925  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7926  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7927  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7928  Dreissena polymorpha  zebra mussel  United States of America        WV
# 7929  Dreissena polymorpha  zebra mussel  United States of America        WV
#
#      County                                           Locality   Latitude  \
# 0       NaN  Lake Winnipeg, at Winnipeg Beach, Manitoba, Ca...  50.508210
# 1       NaN  Lake Winnipeg, at Gimli Harbour, Manitoba, Canada  50.631820
# 2       NaN   Lake Winnipeg, at Willow Point, Manitoba, Canada  50.603860
# 3       NaN  Lake Winnipeg, at Silver Harbour, Manitoba, Ca...  50.811610
# 4       NaN  Lake Winnipeg, at Balsam Bay Harbour, Manitoba...  50.473810
# ...     ...                                                ...        ...
# 7925   Wood  Ohio River (R.M. 205) [just below Belleville L...  39.105370
# 7926   Wood  Ohio River (R.M. 176) at Muskingum Island at B...  39.377380
# 7927   Wood  Ohio River (R.M. 175.2) about 3 miles downrive...  39.380695
# 7928   Wood  Ohio River at RM 205.2, ORSANCO survey site OH...  39.099000
# 7929   Wood  Ohio River at RM 204.4, ORSANCO survey site OH...  39.111720
#
#       Longitude     Drainage Name  Year  Month   Day
# 0    -96.967380               NaN  2013   10.0  17.0
# 1    -96.983560               NaN  2013   10.0  11.0
# 2    -96.957810               NaN  2013   10.0   NaN
# 3    -96.963260               NaN  2013   10.0   NaN
# 4    -96.583570               NaN  2013   10.0   NaN
# ...         ...               ...   ...    ...   ...
# 7925 -81.740356  Upper Ohio-Shade  1998    NaN   NaN
# 7926 -81.491425  Upper Ohio-Shade  1998    NaN   NaN
# 7927 -81.489883  Upper Ohio-Shade  1999    NaN   NaN
# 7928 -81.741470  Upper Ohio-Shade  2005   10.0   5.0
# 7929 -81.737920  Upper Ohio-Shade  2010   10.0  19.0
#
# [7928 rows x 16 columns]

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(zebra_mussels["Latitude"], zebra_mussels["Longitude"])
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Longitude'>

# %%
z_map = folium.Map(location=[45.5236, -95.6750], zoom_start=5)
zebra_mussels.apply(lambda row:folium.Marker(location=[row["Latitude"], row["Longitude"]] ).add_to(z_map), axis=1)
z_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b0a4491753d94f829c723647c1705463%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b0a4491753d94f829c723647c1705463%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b0a4491753d94f829c723647c1705463%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b0a4491753d94f829c723647c1705463%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B45.5236%2C%20-95.675%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
zebra_mussels["Latitude"] = np.radians(zebra_mussels["Latitude"])
zebra_mussels["Longitude"] = np.radians(zebra_mussels["Longitude"])

# %%
from sklearn.cluster import KMeans ,AgglomerativeClustering

# # creates 5 clusters using hierarchical clustering.
# agc = AgglomerativeClustering(n_clusters =5, affinity='euclidean', linkage='ward')
# zebras_frogs['pickup cluster'] = agc.fit_predict(zebras_frogs[['Latitude','Longitude']])

# creates 5 clusters using k-means clustering algorithm.
kmeans = KMeans(5)
clusters = kmeans.fit_predict(zebra_mussels[['Latitude','Longitude']])
zebra_mussels['cluster'] = kmeans.predict(zebra_mussels[['Latitude','Longitude']])
zebra_mussels.head()
# Out:
#    Specimen Number  Species ID              Group        Family  \
# 0           615085           5  Mollusks-Bivalves  Dreissenidae
# 1           615297           5  Mollusks-Bivalves  Dreissenidae
# 2           615300           5  Mollusks-Bivalves  Dreissenidae
# 3           615301           5  Mollusks-Bivalves  Dreissenidae
# 4           615302           5  Mollusks-Bivalves  Dreissenidae
#
#         Scientific Name   Common Name Country     State County  \
# 0  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 1  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 2  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 3  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 4  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
#
#                                             Locality  Latitude  Longitude  \
# 0  Lake Winnipeg, at Winnipeg Beach, Manitoba, Ca...  0.881535  -1.692400
# 1  Lake Winnipeg, at Gimli Harbour, Manitoba, Canada  0.883692  -1.692682
# 2   Lake Winnipeg, at Willow Point, Manitoba, Canada  0.883204  -1.692233
# 3  Lake Winnipeg, at Silver Harbour, Manitoba, Ca...  0.886830  -1.692328
# 4  Lake Winnipeg, at Balsam Bay Harbour, Manitoba...  0.880934  -1.685701
#
#   Drainage Name  Year  Month   Day  cluster
# 0           NaN  2013   10.0  17.0        4
# 1           NaN  2013   10.0  11.0        4
# 2           NaN  2013   10.0   NaN        4
# 3           NaN  2013   10.0   NaN        4
# 4           NaN  2013   10.0   NaN        4

# %%
zebra_mussels[zebra_mussels['cluster'] == 2].head()
# Out:
#       Specimen Number  Species ID              Group        Family  \
# 1375           158363           5  Mollusks-Bivalves  Dreissenidae
# 1376           116453           5  Mollusks-Bivalves  Dreissenidae
# 1377          1407253           5  Mollusks-Bivalves  Dreissenidae
# 1378          1407254           5  Mollusks-Bivalves  Dreissenidae
# 1379          1407257           5  Mollusks-Bivalves  Dreissenidae
#
#            Scientific Name   Common Name                   Country State  \
# 1375  Dreissena polymorpha  zebra mussel  United States of America    AL
# 1376  Dreissena polymorpha  zebra mussel  United States of America    AL
# 1377  Dreissena polymorpha  zebra mussel  United States of America    AL
# 1378  Dreissena polymorpha  zebra mussel  United States of America    AL
# 1379  Dreissena polymorpha  zebra mussel  United States of America    AL
#
#        County                                           Locality  Latitude  \
# 1375      NaN                                  Guntersville Lake  0.601216
# 1376  Colbert  Tennessee River (R.M. 250.0) (Upper Pickwick R...  0.606219
# 1377  Colbert                       Tennessee River, at Florence  0.606948
# 1378  Colbert                       Tennessee River, at Florence  0.607146
# 1379  Colbert     Tennessee River, ~2 mi. downstream of Florence  0.606889
#
#       Longitude      Drainage Name  Year  Month   Day  cluster
# 1375  -1.504823  Guntersville Lake  1995    NaN   NaN        2
# 1376  -1.531741      Pickwick Lake  1992    8.0  25.0        2
# 1377  -1.530533      Pickwick Lake  2017    6.0  19.0        2
# 1378  -1.529796      Pickwick Lake  2017    6.0  20.0        2
# 1379  -1.530719      Pickwick Lake  2017    6.0  21.0        2

# %%
zebra_mussels[zebra_mussels['cluster'] == 4].head()
# Out:
#    Specimen Number  Species ID              Group        Family  \
# 0           615085           5  Mollusks-Bivalves  Dreissenidae
# 1           615297           5  Mollusks-Bivalves  Dreissenidae
# 2           615300           5  Mollusks-Bivalves  Dreissenidae
# 3           615301           5  Mollusks-Bivalves  Dreissenidae
# 4           615302           5  Mollusks-Bivalves  Dreissenidae
#
#         Scientific Name   Common Name Country     State County  \
# 0  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 1  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 2  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 3  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
# 4  Dreissena polymorpha  zebra mussel  Canada  Manitoba    NaN
#
#                                             Locality  Latitude  Longitude  \
# 0  Lake Winnipeg, at Winnipeg Beach, Manitoba, Ca...  0.881535  -1.692400
# 1  Lake Winnipeg, at Gimli Harbour, Manitoba, Canada  0.883692  -1.692682
# 2   Lake Winnipeg, at Willow Point, Manitoba, Canada  0.883204  -1.692233
# 3  Lake Winnipeg, at Silver Harbour, Manitoba, Ca...  0.886830  -1.692328
# 4  Lake Winnipeg, at Balsam Bay Harbour, Manitoba...  0.880934  -1.685701
#
#   Drainage Name  Year  Month   Day  cluster
# 0           NaN  2013   10.0  17.0        4
# 1           NaN  2013   10.0  11.0        4
# 2           NaN  2013   10.0   NaN        4
# 3           NaN  2013   10.0   NaN        4
# 4           NaN  2013   10.0   NaN        4

# %%
terrain = sns.color_palette(palette='terrain',n_colors=10)
plasma = sns.color_palette(palette='plasma',n_colors=10)
rainbow = sns.color_palette(palette='rainbow',n_colors=6)

from bokeh.io import output_notebook
from bokeh.layouts import gridplot,row,column
from bokeh.plotting import figure,show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1163">Loading BokehJS ...</span>
#     </div>

# %%
print('data dimensions:',zebra_mussels.shape)
# Out:
# data dimensions: (7928, 17)
